# %% [markdown]
# ### Basic Data Types:
# ##### Scaler data types-:
#
# * Integer
# * Boolean-True or False
# * Float
# * complex
#
#
# ##### Aggreagate Data Types-:
# * String
# * Lists
# * tuples
# * sets
# * dictionaries

# %%
##numeric datatypes-integer,complex,float
a=70
print(a)
# Out:
# 70

# %%
o1=70
print(o1)
# Out:
# 70

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
#create an object of the boolean class:
b=False
print(b)
print(type(b))
# Out:
# False
# <class 'bool'>

# %%
c=6+9j
print(c)
print(type(c))
# Out:
# (6+9j)
# <class 'complex'>

# %%
###lets create a float object
d=16.5
print(d)
print(type(d))
# Out:
# 16.5
# <class 'float'>

# %% [markdown]
# ##### Aggregate Data Types:

# %%
###tuple--we used round brackets/parenthesis to create a tuple. It can also be created with the tuple function. It
### contains elements of mixed datatypes.
aggd1=(18,45,10.8,True,8+3j)

# %%
print(aggd1)
print(type(aggd1))
# Out:
# (18, 45, 10.8, True, (8+3j))
# <class 'tuple'>

# %%
###Python is case sensitive

# %%
###List--we used box brackets to create a list. It can also be created with the list function. It
### contains elements of mixed datatypes.
aggd2=[18,45,10.8,True,8+3j]

# %%
print(aggd2)
print(type(aggd2))
# Out:
# [18, 45, 10.8, True, (8+3j)]
# <class 'list'>

# %%
#### hashes are used to write comments/remarks while you code.whatever you write after a hash is automatically turned 
#### into a comment and is not executed

# %%
wrong='false'
wrong_1=False
wrong
# Out:
# 'false'

# %%
print(type(wrong))
print(type(wrong_1))
# Out:
# <class 'str'>
# <class 'bool'>

# %%
string1='Python Session'
string1
# Out:
# 'Python Session'

# %%
len(string1)
# Out:
# 14

# %%
###space is considered an element in python.

# %%
### When is the print function mandatory?

# %%
x=89
y=89.5
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
d="Wecome to day two"
type(d)
# Out:
# str

# %%
#multi line string values:
e="""Welcome to day 2
 we will learn about the remaining data structures"""
type(e)
# Out:
# str

# %%
len(e)
# Out:
# 67

# %%
### slice out the 't' of two from the string object 'd'

# %%
d[-3]
# Out:
# 't'

# %%
###immutability:'modifiable'
str1='Python'
str1[-1]='N'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 ###immutability:'modifiable'
#       2 str1='Python'
# ----> 3 str1[-1]='N'
#
# TypeError: 'str' object does not support item assignment

# %%
str2='This is the second session'
###slice out 'second' from the above str2

# %%
str2[12:18]
# Out:
# 'second'

# %%
obj=str2[12:18]
mod_obj=obj[::-1]
mod_obj
# Out:
# 'dnoces'

# %%
str3='899'
type(str3)
# Out:
# str

# %%
str4='on Python'

# %%
### join method: inbuilt str function which is used to join elements of a string object using a separater
new_str='_'.join(str4)
new_str
# Out:
# 'o_n_ _P_y_t_h_o_n'

# %%
str2+str4
# Out:
# 'This is the second sessionon Python'

# %%
t1=(5,6,7,8)
t2=(7,8,9,10)
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
t1+t2
# Out:
# (5, 6, 7, 8, 7, 8, 9, 10)

# %%
#### None of the inbuilt datatypes support mathematical operations

# %%
### convert the first character in a string value to its uppercase:
str5='error in syntax'
str5_m=str5.capitalize()
str5_m
# Out:
# 'Error in syntax'

# %%
print(str5.upper())
# Out:
# ERROR IN SYNTAX

# %%
#Q) convert the first character of each substring to its uppercase-use str5
str_title=str5.title()
str_title
# Out:
# 'Error In Syntax'

# %%
#Q) Read the string object in the reverse order.
print(str5)
# Out:
# error in syntax

# %%
str5[::-1]
#since we must start reading from end we use -1, as entire string has to be read we denote by :: is it correcr
# Out:
# 'xatnys ni rorre'

# %%
### difference between a list and a Tuple:
list2=list((8,2.5,True,4+5j,'text',(4,5)))

# %%
print(type(list2))
# Out:
# <class 'list'>

# %%
tuple1=tuple((8,2.5,True,4+5j,'text',(4,5)))
print(tuple1)
print(type(tuple1))
# Out:
# (8, 2.5, True, (4+5j), 'text', (4, 5))
# <class 'tuple'>

# %% [markdown]
# ##### Lists are mutable,but tuples are immutable.

# %%
#replace the string value 'text' in list2 with 'value'
list2[-2]='value'
list2
# Out:
# [8, 2.5, True, (4+5j), 'value', (4, 5)]

# %%
###Do the same replacement for tuple1
tuple1[-2]='value'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 ###Do the same replacement for tuple1
# ----> 2 tuple1[-2]='value'
#
# TypeError: 'tuple' object does not support item assignment

# %%
list2=list(tuple1)  #typecasting-changing one datatype to another
print(type(list2))
# Out:
# <class 'list'>

# %%
x=10
x_str=str(x)
print(x_str)
print(type(x_str))
# Out:
# 10
# <class 'str'>

# %% [markdown]
# #### Sets are an unordered collection of elements,that is mutable,does not support duplicate entries.

# %%
set1=set((8,2.5,True,4+5j,'text',(4,5)))
set2={8,2.5,True,4+5j,'text',(4,5)}
print(type(set1))
print(type(set2))
# Out:
# <class 'set'>
# <class 'set'>

# %%
set1
# Out:
# {(4+5j), (4, 5), 2.5, 8, True, 'text'}

# %%
set3={True,5+6j,'value',1,8.9}   #sets do not allow duplicates.
set3
# Out:
# {(5+6j), 8.9, True, 'value'}

# %%
####complex, float, boolean, integer,string

# %%
set3[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 set3[-1]
#
# TypeError: 'set' object is not subscriptable

# %%
#### as Sets are unordered we cant fix the positional index of the elements as we are not aware of the order in which
#### the elements of a set is stored.

# %%
set3
# Out:
# {(5+6j), 8.9, True, 'value'}

# %%
set3.add(35)

# %%
set3
# Out:
# {(5+6j), 35, 8.9, True, 'value'}

# %%
set3.remove(True)

# %%
set3
# Out:
# {(5+6j), 35, 8.9, 'value'}

# %%
#union of two sets:
set4=set1.union(set3)
set4
# Out:
# {(4+5j), (4, 5), (5+6j), 2.5, 35, 8, 8.9, True, 'text', 'value'}

# %%
set5={2.5,19.6,'Text',9+2j,False,8,10}
set5
# Out:
# {(9+2j), 10, 19.6, 2.5, 8, False, 'Text'}

# %%
set4
# Out:
# {(4+5j), (4, 5), (5+6j), 2.5, 35, 8, 8.9, True, 'text', 'value'}

# %%
###intersection of two sets will give us only the elements common to bothe the sets:
set4.intersection(set5)
# Out:
# {2.5, 8}

# %%
### Q)find the difference between set 4 and set5-->elements of set4 not present in set5

# %%
set6=set4.difference(set5)

# %%
set6
# Out:
# {(4+5j), (4, 5), (5+6j), 35, 8.9, True, 'text', 'value'}

# %%
#say something

# %% [markdown]
# ##### Dictionaries is an internal data structure that stores values in key:value pairs.

# %%
dict1={1:'one',2:'two','Three':3,'Four':4}
dict1
# Out:
# {1: 'one', 2: 'two', 'Three': 3, 'Four': 4}

# %%
print(type(dict1))
# Out:
# <class 'dict'>

# %%
dict1.keys()
# Out:
# dict_keys([1, 2, 'Three', 'Four'])

# %%
dict1.values()
# Out:
# dict_values(['one', 'two', 3, 4])

# %%
dict1['Four']
# Out:
# 4

# %%
dict1[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 dict1[-1]
#
# KeyError: -1

# %%
#Q) update the value of the key 'Three' from 3 to 30

# %%
dict1['Three']=30
print(dict1)
# Out:
# {1: 'one', 2: 'two', 'Three': 30, 'Four': 4}

# %%
#Q) add a new element with the key value 5 and assign this to 50

# %%
dict1[5]=50
dict1
# Out:
# {1: 'one', 2: 'two', 'Three': 30, 'Four': 4, 5: 50}

# %%
#Q) create a nested dictionary with two keys dict1 and dict2

# %%
#nested dictionaries are dictionaries with a dictionary.
Dict3={'dict0':{6:'six'},'dict1':{7:'seven'}}
Dict3
# Out:
# {'dict0': {6: 'six'}, 'dict1': {7: 'seven'}}

# %%
#Q) delete the last key value pair('Four: 4')

# %%
del dict1['Four']
print(dict1)
# Out:
# {1: 'one', 2: 'two', 'Three': 30, 5: 50}
